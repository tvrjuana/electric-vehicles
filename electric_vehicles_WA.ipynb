# %%
#importing necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

# %matplotlib inline

# %%
#reading csv file 
ev = pd.read_csv("data/Electric_Vehicle_Population_Data.csv")

display(ev.head())
display(ev.info())
# Out:
#    VIN (1-10)    County     City State  Postal Code  Model Year    Make  \
# 0  5YJXCAE26J    Yakima   Yakima    WA      98908.0        2018   TESLA
# 1  JHMZC5F37M    Kitsap  Poulsbo    WA      98370.0        2021   HONDA
# 2  5YJ3E1EB0K      King  Seattle    WA      98199.0        2019   TESLA
# 3  1N4AZ0CP5D      King  Seattle    WA      98119.0        2013  NISSAN
# 4  5YJSA1E21H  Thurston    Lacey    WA      98516.0        2017   TESLA
#
#      Model                   Electric Vehicle Type  \
# 0  MODEL X          Battery Electric Vehicle (BEV)
# 1  CLARITY  Plug-in Hybrid Electric Vehicle (PHEV)
# 2  MODEL 3          Battery Electric Vehicle (BEV)
# 3     LEAF          Battery Electric Vehicle (BEV)
# 4  MODEL S          Battery Electric Vehicle (BEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 0           Clean Alternative Fuel Vehicle Eligible             238
# 1           Clean Alternative Fuel Vehicle Eligible              47
# ...

# %%
#checking for null values 
ev.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 3
# City                                                   3
# State                                                  0
# Postal Code                                            3
# Model Year                                             0
# Make                                                   0
# Model                                                222
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                 305
# DOL Vehicle ID                                         0
# Vehicle Location                                      33
# Electric Utility                                       3
# ...

# %% [markdown]
# The following features have missing values:
# 1. `County`
# 2. `City`
# 3. `Postal Code`
# 4. `Model`
# 5. `Legislative District`
# 6. `Vehicle Location`
# 7. `Electric Utility`
# 8. `2020 Census Tract`
#
# with Model and Legislative District having the most missing values with 222 and 305 respectively.

# %%
#taking a closer look at Legislative District
len(ev['Legislative District'].value_counts())
# Out:
# 49

# %%
#taking a look at the instances that has null values for the Legislative District
null_ld = ev[ev['Legislative District'].isna()]
null_ld.head()
# Out:
#        VIN (1-10)      County        City State  Postal Code  Model Year  \
# 102    1N4AZ0CP1D         NaN         NaN    AP          NaN        2013
# 103    5YJ3E1EA5K         NaN         NaN    BC          NaN        2019
# 57726  2C4RC1H78J      Oldham      Goshen    KY      40026.0        2018
# 59729  WA1VABGE7M     Douglas       Omaha    NE      68102.0        2021
# 59939  1N4AZ1CP4J  Montgomery  Norristown    PA      19403.0        2018
#
#            Make     Model                   Electric Vehicle Type  \
# 102      NISSAN      LEAF          Battery Electric Vehicle (BEV)
# 103       TESLA   MODEL 3          Battery Electric Vehicle (BEV)
# 57726  CHRYSLER  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 59729      AUDI    E-TRON          Battery Electric Vehicle (BEV)
# 59939    NISSAN      LEAF          Battery Electric Vehicle (BEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# ...

# %%
#state from null_ld 
null_ld['State'].value_counts()
# Out:
# CA    83
# VA    35
# MD    29
# TX    19
# CO    11
# NC    10
# AZ     9
# IL     8
# CT     7
# NV     7
# NY     6
# OR     6
# GA     6
# NJ     5
# SC     5
# HI     5
# LA     4
# DC     4
# FL     4
# NE     3
# MA     3
# KS     3
# AR     3
# PA     2
# UT     2
# ID     2
# WY     2
# TN     2
# BC     2
# MO     2
# OH     2
# OK     1
# IN     1
# MS     1
# NH     1
# WI     1
# DE     1
# NM     1
# RI     1
# AK     1
# MN     1
# KY     1
# MI     1
# AL     1
# AP     1
# Name: State, dtype: int64

# %% [markdown]
# I was right! These null values from Legislative District are all states that are not Washington. Since this is only focusing on the state of WA right now, I am going to drop these `Legislative District` null values.

# %%
#dropping null values
ev.dropna(subset=['Legislative District'], inplace=True)

#checking null values 
ev.isna().sum()
# Out:
# VIN (1-10)                                             0
# County                                                 0
# City                                                   0
# State                                                  0
# Postal Code                                            0
# Model Year                                             0
# Make                                                   0
# Model                                                222
# Electric Vehicle Type                                  0
# Clean Alternative Fuel Vehicle (CAFV) Eligibility      0
# Electric Range                                         0
# Base MSRP                                              0
# Legislative District                                   0
# DOL Vehicle ID                                         0
# Vehicle Location                                      27
# Electric Utility                                       0
# ...

# %% [markdown]
# Dropping the null values from Legislative District took away other null values expect for all of `Make` and some `Vehicle Location`

# %%
#taking closer look at instances that have Model as null
null_m = ev[ev['Model'].isna()]

null_m.head()
# Out:
#       VIN (1-10) County         City State  Postal Code  Model Year   Make  \
# 533   YV4ED3UL9P   King  Woodinville    WA      98072.0        2023  VOLVO
# 1740  YV4ED3UW2P   King     Bellevue    WA      98005.0        2023  VOLVO
# 2158  YV4ED3UM9P   King      Seattle    WA      98122.0        2023  VOLVO
# 2221  YV4ED3UW1P   King      Seattle    WA      98125.0        2023  VOLVO
# 2959  YV4ED3UW1P   King      Seattle    WA      98146.0        2023  VOLVO
#
#      Model           Electric Vehicle Type  \
# 533    NaN  Battery Electric Vehicle (BEV)
# 1740   NaN  Battery Electric Vehicle (BEV)
# 2158   NaN  Battery Electric Vehicle (BEV)
# 2221   NaN  Battery Electric Vehicle (BEV)
# 2959   NaN  Battery Electric Vehicle (BEV)
#
#       Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 533   Eligibility unknown as battery range has not b...               0
# 1740  Eligibility unknown as battery range has not b...               0
# ...

# %% [markdown]
# Taking a closer look there's seems to be some connection between the make being Volvo and the model being null. As well as the electric vehicle type and the clean alternative fuel vehicle.

# %%
display(null_m['Make'].value_counts())

display(null_m['Electric Vehicle Type'].value_counts())

display(null_m['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts())

display(null_m['Model Year'].value_counts())
# Out:
# VOLVO    222
# Name: Make, dtype: int64
# Battery Electric Vehicle (BEV)    222
# Name: Electric Vehicle Type, dtype: int64
# Eligibility unknown as battery range has not been researched    222
# Name: Clean Alternative Fuel Vehicle (CAFV) Eligibility, dtype: int64
# 2023    222
# Name: Model Year, dtype: int64

# %% [markdown]
# From here can see that all of the null values have the following as Make - Volvo, Electric Vehicle Type - Battery Electric Vehicle (BEV), Clean Alternative Fuel Vehicle (CAFV) Eligibility, Year - 2023.
#
# Could be that since the cars are new cars (at the time of this analysis) then that is why the model is not know yet. I will not remove this since it gives nice insights into the data.

# %%
#dropping null values of Vehicle Location since there is only 27 missing 
ev.dropna(subset=['Vehicle Location'], inplace=True)

# %%
ev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130111 entries, 0 to 130442
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         130111 non-null  object
#  1   County                                             130111 non-null  object
#  2   City                                               130111 non-null  object
#  3   State                                              130111 non-null  object
#  4   Postal Code                                        130111 non-null  float64
#  5   Model Year                                         130111 non-null  int64
#  6   Make                                               130111 non-null  object
#  7   Model                                              129889 non-null  object
# ...

# %% [markdown]
# Now instead of 130,443 entries have 130,111 which is not bad.
